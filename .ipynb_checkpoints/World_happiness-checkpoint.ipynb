# %% [markdown]
# # Happiness in function of GDP (Scatterplot - Nathan)

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("2020.csv")
x = df["Logged GDP per capita"]
y = df["Ladder score"]

# %%
plt.figure(figsize=(10,10))
plt.scatter(x, y,)

z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,p(x),"r")

plt.xlabel("GDP per Capita", size=12)
plt.ylabel("Happiness ladder score", size=12)
plt.title("Happiness in function of GDP", size=14)
plt.grid(True)
plt.show()

# %% [markdown]
# # Happiness with seaborn lib (Barchart - santiago)

# %%
import pandas as pd
tips = pd.read_csv('2020.csv')
# party_counts = pd.crosstab(tips['Country name'], tips['Freedom to make life choices'])
data = tips[['Country name', 'Freedom to make life choices']]

# %%
data[:10].sort_values(by='Freedom to make life choices')
# Out:
#   Country name  Freedom to make life choices
# 8      Austria                      0.899989
# 9   Luxembourg                      0.905636
# 5  Netherlands                      0.908548
# 2  Switzerland                      0.921337
# 7  New Zealand                      0.936217
# 6       Sweden                      0.939144
# 3      Iceland                      0.948892
# 0      Finland                      0.949172
# 1      Denmark                      0.951444
# 4       Norway                      0.955750

# %%
import seaborn as sns
 
sns.barplot(x='Freedom to make life choices', y='Country name', data=data[:10].sort_values(by='Freedom to make life choices'), orient='h')
